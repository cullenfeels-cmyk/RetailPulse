# %% [markdown]
# # RetailPulse – Streamlit Dashboard
#
# ## AI-Powered Retail Analytics Dashboard
#
# **Author:** Gulafsha
#
# ### Objective
#
# Create an interactive dashboard for RetailPulse to visualize:
#
# - Executive KPIs
# - Sales Performance
# - Customer Analytics
# - Demand Forecast
# - Inventory Optimization
#
# ### Business Value
#
# - Real-time insights
# - Better decision making
# - Interactive exploration
# - AI-powered analytics

# %%
import pandas as pd

print("Libraries Loaded Successfully ✅")
# Out:
# Libraries Loaded Successfully ✅

# %%
summary = pd.read_csv("../outputs/revenue_summary.csv")

summary
# Out:
#             Metric         Value
# 0    Total Revenue  1.027176e+07
# 1   Total Quantity  5.812947e+06
# 2     Total Orders  2.095100e+04
# 3  Total Customers  4.312000e+03
# 4   Total Products  4.251000e+03

# %%
monthly_sales = pd.read_csv("../outputs/monthly_sales.csv")

monthly_sales.head()
# Out:
#      Month     Revenue
# 0  2009-12  822483.950
# 1  2010-01  651155.112
# 2  2010-02  551504.726
# 3  2010-03  830915.261
# 4  2010-04  678875.252

# %%
top_products = pd.read_csv("../outputs/top_products.csv")

top_products.head()
# Out:
#                           Description    Revenue
# 0                              Manual  262589.86
# 1            REGENCY CAKESTAND 3 TIER  169912.76
# 2  WHITE HANGING HEART T-LIGHT HOLDER  160345.63
# 3                      DOTCOM POSTAGE  116408.71
# 4       ASSORTED COLOUR BIRD ORNAMENT   72890.19

# %%
top_customers = pd.read_csv("../outputs/top_customers.csv")

top_customers.head()
# Out:
#    Customer ID    Revenue
# 0      18102.0  349164.35
# 1      14646.0  248396.50
# 2      14156.0  196549.74
# 3      14911.0  152121.22
# 4      13694.0  131443.19

# %%
top_countries = pd.read_csv("../outputs/top_countries.csv")

top_countries.head()
# Out:
#           Country      Revenue
# 0  United Kingdom  8812311.833
# 1            EIRE   380909.570
# 2     Netherlands   268784.350
# 3         Germany   202025.391
# 4          France   147103.140

# %%
inventory = pd.read_csv("../outputs/inventory_optimization.csv")

inventory.head()
# Out:
#   StockCode                  Description  Total_Quantity  Total_Revenue  \
# 0     10002  INFLATABLE POLITICAL GLOBE             7971        6333.76
# 1    10002R        ROBOT PENCIL SHARPNER               4          20.57
# 2     10080     GROOVY CACTUS INFLATABLE              12          10.20
# 3     10109         BENDY COLOUR PENCILS               4           1.68
# 4     10120                 DOGGY RUBBER             487         105.57
#
#    Total_Orders  Average_Daily_Demand  Maximum_Daily_Demand  Safety_Stock  \
# 0           310             25.879870                   400        4200.0
# 1             3              1.333333                     2          21.0
# 2             5              2.400000                     6          63.0
# 3             1              4.000000                     4          42.0
# 4            47             10.361702                    60         630.0
#
#    Reorder_Level Inventory_Status
# 0     181.159091          Healthy
# ...

# %%
forecast = pd.read_csv("../outputs/demand_forecast.csv")

forecast.head()
# Out:
#            ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0  2009-12-01  28570.420043  19005.958600  52332.314070  28570.420043
# 1  2009-12-02  28540.080630  14490.848375  47586.455403  28540.080630
# 2  2009-12-03  28509.741217  22319.385140  55752.083065  28509.741217
# 3  2009-12-04  28479.401804  13022.706503  45942.546353  28479.401804
# 4  2009-12-05  28449.062391  -5862.933337  27973.347827  28449.062391
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  28570.420043     7366.077179           7366.077179           7366.077179
# 1  28540.080630     2456.728277           2456.728277           2456.728277
# 2  28509.741217     9734.176894           9734.176894           9734.176894
# 3  28479.401804      343.722258            343.722258            343.722258
# 4  28449.062391   -17956.027635         -17956.027635         -17956.027635
#
#          weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# ...

# %%
summary = pd.read_csv("../outputs/revenue_summary.csv")
monthly = pd.read_csv("../outputs/monthly_sales.csv")
products = pd.read_csv("../outputs/top_products.csv")
customers = pd.read_csv("../outputs/top_customers.csv")
countries = pd.read_csv("../outputs/top_countries.csv")
forecast = pd.read_csv("../outputs/demand_forecast.csv")

print("All files loaded successfully ✅")
# Out:
# All files loaded successfully ✅

# %%
summary.head()
# Out:
#             Metric         Value
# 0    Total Revenue  1.027176e+07
# 1   Total Quantity  5.812947e+06
# 2     Total Orders  2.095100e+04
# 3  Total Customers  4.312000e+03
# 4   Total Products  4.251000e+03

# %%
monthly.head()
# Out:
#      Month     Revenue
# 0  2009-12  822483.950
# 1  2010-01  651155.112
# 2  2010-02  551504.726
# 3  2010-03  830915.261
# 4  2010-04  678875.252

# %%
products.head()
# Out:
#                           Description    Revenue
# 0                              Manual  262589.86
# 1            REGENCY CAKESTAND 3 TIER  169912.76
# 2  WHITE HANGING HEART T-LIGHT HOLDER  160345.63
# 3                      DOTCOM POSTAGE  116408.71
# 4       ASSORTED COLOUR BIRD ORNAMENT   72890.19

# %%
customers.head()
# Out:
#    Customer ID    Revenue
# 0      18102.0  349164.35
# 1      14646.0  248396.50
# 2      14156.0  196549.74
# 3      14911.0  152121.22
# 4      13694.0  131443.19

# %%
countries.head()
# Out:
#           Country      Revenue
# 0  United Kingdom  8812311.833
# 1            EIRE   380909.570
# 2     Netherlands   268784.350
# 3         Germany   202025.391
# 4          France   147103.140

# %%
forecast.head()
# Out:
#            ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0  2009-12-01  28570.420043  19005.958600  52332.314070  28570.420043
# 1  2009-12-02  28540.080630  14490.848375  47586.455403  28540.080630
# 2  2009-12-03  28509.741217  22319.385140  55752.083065  28509.741217
# 3  2009-12-04  28479.401804  13022.706503  45942.546353  28479.401804
# 4  2009-12-05  28449.062391  -5862.933337  27973.347827  28449.062391
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  28570.420043     7366.077179           7366.077179           7366.077179
# 1  28540.080630     2456.728277           2456.728277           2456.728277
# 2  28509.741217     9734.176894           9734.176894           9734.176894
# 3  28479.401804      343.722258            343.722258            343.722258
# 4  28449.062391   -17956.027635         -17956.027635         -17956.027635
#
#          weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# ...
