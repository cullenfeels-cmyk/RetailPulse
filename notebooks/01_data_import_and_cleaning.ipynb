# %%
print("Hello RetailPulse!")
# Out:
# Hello RetailPulse!

# %%
print("Hello RetailPulse!")
# Out:
# Hello RetailPulse!

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python311\python.exe

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python311\python.exe

# %%
import sys
print(sys.executable)
# Out:
# d:\RetailPulse\.venv\Scripts\python.exe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries working ✅")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#       5
#       6 print("All libraries working ✅")
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries working ✅")
# Out:
# All libraries working ✅

# %%
print(sys.executable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(sys.executable)
#
# NameError: name 'sys' is not defined

# %%
import sys
print(sys.executable)
# Out:
# d:\RetailPulse\.venv\Scripts\python.exe

# %%
import pandas as pd

df = pd.read_csv('../data/your_file.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('../data/your_file.csv')
#       4 df.head()
#
# File d:\RetailPulse\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

df = pd.read_excel('../data/online_retail_II.xlsx')
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.shape
# Out:
# (525461, 8)

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  525461.000000                         525461  525461.000000
# mean       10.337667  2010-06-28 11:37:36.845017856       4.688834
# min     -9600.000000            2009-12-01 07:45:00  -53594.360000
# 25%         1.000000            2010-03-21 12:20:00       1.250000
# 50%         3.000000            2010-07-06 09:51:00       2.100000
# 75%        10.000000            2010-10-15 12:45:00       4.210000
# max     19152.000000            2010-12-09 20:01:00   25111.090000
# std       107.424110                            NaN     146.126914
#
#          Customer ID
# count  417534.000000
# mean    15360.645478
# min     12346.000000
# 25%     13983.000000
# 50%     15311.000000
# 75%     16799.000000
# max     18287.000000
# std      1680.811316

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
df = df.dropna(subset=['Customer ID'])

# %%
df = df.dropna(subset=['Description'])

# %%
df['Customer ID'] = df['Customer ID'].astype(str)

# %%
df = df[df['Price'] > 0]

# %%
df['Revenue'] = df['Quantity'] * df['Price']

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 417503 entries, 0 to 525460
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      417503 non-null  object
#  1   StockCode    417503 non-null  object
#  2   Description  417503 non-null  object
#  3   Quantity     417503 non-null  int64
#  4   InvoiceDate  417503 non-null  datetime64[ns]
#  5   Price        417503 non-null  float64
#  6   Customer ID  417503 non-null  object
#  7   Country      417503 non-null  object
#  8   Revenue      417503 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 31.9+ MB
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# ...

# %%
top_products = df.groupby('Description')['Revenue'].sum().sort_values(ascending=False).head(10)
top_products
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER     148876.66
# REGENCY CAKESTAND 3 TIER               136866.30
# ASSORTED COLOUR BIRD ORNAMENT           69854.96
# JUMBO BAG RED RETROSPOT                 51608.40
# POSTAGE                                 45520.86
# ROTATING SILVER ANGELS T-LIGHT HLDR     39902.10
# PAPER CHAIN KIT 50'S CHRISTMAS          36866.45
# PARTY BUNTING                           34998.70
# JUMBO BAG STRAWBERRY                    33893.70
# VINTAGE UNION JACK BUNTING              33546.96
# Name: Revenue, dtype: float64

# %%
country_revenue = df.groupby('Country')['Revenue'].sum().sort_values(ascending=False)
country_revenue.head(10)
# Out:
# Country
# United Kingdom    7038549.633
# EIRE               328216.410
# Netherlands        263863.410
# Germany            196290.351
# France             129773.830
# Sweden              50859.510
# Denmark             46972.950
# Switzerland         43343.410
# Spain               37084.900
# Australia           30051.800
# Name: Revenue, dtype: float64

# %%
top_customers = df.groupby('Customer ID')['Revenue'].sum().sort_values(ascending=False).head(10)
top_customers
# Out:
# Customer ID
# 18102.0    341776.73
# 14646.0    243853.05
# 14156.0    183180.55
# 14911.0    137675.91
# 13694.0    128172.42
# 17511.0     83760.60
# 15061.0     82162.74
# 16684.0     75610.17
# 13089.0     55828.31
# 16754.0     54558.18
# Name: Revenue, dtype: float64

# %%
df['YearMonth'] = df['InvoiceDate'].dt.to_period('M')

monthly_sales = df.groupby('YearMonth')['Revenue'].sum()
monthly_sales
# Out:
# YearMonth
# 2009-12     663272.050
# 2010-01     531952.902
# 2010-02     489399.586
# 2010-03     635996.481
# 2010-04     560635.022
# 2010-05     559924.550
# 2010-06     571459.910
# 2010-07     562785.900
# 2010-08     587256.460
# 2010-09     781033.301
# 2010-10     964989.780
# 2010-11    1134879.282
# 2010-12     304623.350
# Freq: M, Name: Revenue, dtype: float64

# %%
import matplotlib.pyplot as plt

monthly_sales.plot()
plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# %%
monthly_sales.plot(ax=axes[0,0])
axes[0,0].set_title("Monthly Revenue Trend")
axes[0,0].set_xlabel("Month")
axes[0,0].set_ylabel("Revenue")
# Out:
# Text(4.444444444444452, 0.5, 'Revenue')

# %%
top_products = df.groupby('Description')['Revenue'].sum().sort_values(ascending=False).head(10)

top_products.plot(kind='bar', ax=axes[0,1])
axes[0,1].set_title("Top 10 Products")
axes[0,1].set_ylabel("Revenue")
# Out:
# Text(638.5353535353535, 0.5, 'Revenue')

# %%
country_revenue = df.groupby('Country')['Revenue'].sum().sort_values(ascending=False).head(10)

country_revenue.plot(kind='bar', ax=axes[1,0])
axes[1,0].set_title("Top Countries by Revenue")
axes[1,0].set_ylabel("Revenue")
# Out:
# Text(4.444444444444452, 0.5, 'Revenue')

# %%
top_customers = df.groupby('Customer ID')['Revenue'].sum().sort_values(ascending=False).head(10)

top_customers.plot(kind='bar', ax=axes[1,1])
axes[1,1].set_title("Top Customers")
axes[1,1].set_ylabel("Revenue")
# Out:
# Text(638.5353535353535, 0.5, 'Revenue')

# %%
plt.tight_layout()
plt.show()

# %%
plt.style.use('ggplot')

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')

fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# 1. Monthly Revenue
monthly_sales.plot(ax=axes[0,0])
axes[0,0].set_title("Monthly Revenue Trend")

# 2. Top Products
top_products = df.groupby('Description')['Revenue'].sum().sort_values(ascending=False).head(10)
top_products.plot(kind='bar', ax=axes[0,1])
axes[0,1].set_title("Top Products")

# 3. Country Revenue
country_revenue = df.groupby('Country')['Revenue'].sum().sort_values(ascending=False).head(10)
country_revenue.plot(kind='bar', ax=axes[1,0])
axes[1,0].set_title("Top Countries")

# 4. Top Customers
top_customers = df.groupby('Customer ID')['Revenue'].sum().sort_values(ascending=False).head(10)
top_customers.plot(kind='bar', ax=axes[1,1])
axes[1,1].set_title("Top Customers")

plt.tight_layout()
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import sys
print(sys.executable)
# Out:
# d:\RetailPulse\venv\Scripts\python.exe

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.5

# %%
import pandas as pd

# %%
file_path = "../data/online_retail_II.xlsx"

df = pd.read_excel(file_path)

print("Dataset Loaded Successfully!")
# Out:
# Dataset Loaded Successfully!

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.shape
# Out:
# (525461, 8)

# %%
(525461, 8)
# Out:
# (525461, 8)

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[us]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), object(3), str(1)
# memory usage: 38.8+ MB

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(6865)

# %%
df.describe()
# Out:
#             Quantity                 InvoiceDate          Price    Customer ID
# count  525461.000000                      525461  525461.000000  417534.000000
# mean       10.337667  2010-06-28 11:37:36.845018       4.688834   15360.645478
# min     -9600.000000         2009-12-01 07:45:00  -53594.360000   12346.000000
# 25%         1.000000         2010-03-21 12:20:00       1.250000   13983.000000
# 50%         3.000000         2010-07-06 09:51:00       2.100000   15311.000000
# 75%        10.000000         2010-10-15 12:45:00       4.210000   16799.000000
# max     19152.000000         2010-12-09 20:01:00   25111.090000   18287.000000
# std       107.424110                         NaN     146.126914    1680.811316

# %%
import pandas as pd

# %%
file_path = "../data/online_retail_II.xlsx"

df = pd.read_excel(file_path)

print("Dataset Loaded Successfully!")
# Out:
# Dataset Loaded Successfully!

# %%
file_path = "../data/online_retail_II.xlsx"

# %%
df = pd.read_excel(file_path)

# %%
print("Dataset Loaded Successfully!")
# Out:
# Dataset Loaded Successfully!

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.shape
# Out:
# (525461, 8)

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64

# %%
df.describe()
# Out:
#             Quantity                 InvoiceDate          Price    Customer ID
# count  525461.000000                      525461  525461.000000  417534.000000
# mean       10.337667  2010-06-28 11:37:36.845018       4.688834   15360.645478
# min     -9600.000000         2009-12-01 07:45:00  -53594.360000   12346.000000
# 25%         1.000000         2010-03-21 12:20:00       1.250000   13983.000000
# 50%         3.000000         2010-07-06 09:51:00       2.100000   15311.000000
# 75%        10.000000         2010-10-15 12:45:00       4.210000   16799.000000
# max     19152.000000         2010-12-09 20:01:00   25111.090000   18287.000000
# std       107.424110                         NaN     146.126914    1680.811316

# %%
df.duplicated().sum()
# Out:
# np.int64(6865)

# %%
df.describe()
# Out:
#             Quantity                 InvoiceDate          Price    Customer ID
# count  525461.000000                      525461  525461.000000  417534.000000
# mean       10.337667  2010-06-28 11:37:36.845018       4.688834   15360.645478
# min     -9600.000000         2009-12-01 07:45:00  -53594.360000   12346.000000
# 25%         1.000000         2010-03-21 12:20:00       1.250000   13983.000000
# 50%         3.000000         2010-07-06 09:51:00       2.100000   15311.000000
# 75%        10.000000         2010-10-15 12:45:00       4.210000   16799.000000
# max     19152.000000         2010-12-09 20:01:00   25111.090000   18287.000000
# std       107.424110                         NaN     146.126914    1680.811316

# %%
df.duplicated().sum()
# Out:
# np.int64(6865)

# %%
df.describe()
# Out:
#             Quantity                 InvoiceDate          Price    Customer ID
# count  525461.000000                      525461  525461.000000  417534.000000
# mean       10.337667  2010-06-28 11:37:36.845018       4.688834   15360.645478
# min     -9600.000000         2009-12-01 07:45:00  -53594.360000   12346.000000
# 25%         1.000000         2010-03-21 12:20:00       1.250000   13983.000000
# 50%         3.000000         2010-07-06 09:51:00       2.100000   15311.000000
# 75%        10.000000         2010-10-15 12:45:00       4.210000   16799.000000
# max     19152.000000         2010-12-09 20:01:00   25111.090000   18287.000000
# std       107.424110                         NaN     146.126914    1680.811316

# %%
df_clean = df.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_clean = df.copy()
#
# NameError: name 'df' is not defined

# %%
df_clean[df_clean["Invoice"].astype(str).str.startswith("C")].head()
# Out:
#      Invoice StockCode                    Description  Quantity  \
# 178  C489449     22087       PAPER BUNTING WHITE LACE       -12
# 179  C489449    85206A   CREAM FELT EASTER EGG BASKET        -6
# 180  C489449     21895  POTTING SHED SOW 'N' GROW SET        -4
# 181  C489449     21896             POTTING SHED TWINE        -6
# 182  C489449     22083     PAPER CHAIN KIT RETRO SPOT       -12
#
#             InvoiceDate  Price  Customer ID    Country
# 178 2009-12-01 10:33:00   2.95      16321.0  Australia
# 179 2009-12-01 10:33:00   1.65      16321.0  Australia
# 180 2009-12-01 10:33:00   4.25      16321.0  Australia
# 181 2009-12-01 10:33:00   2.10      16321.0  Australia
# 182 2009-12-01 10:33:00   2.95      16321.0  Australia

# %%
cancelled_orders = df_clean["Invoice"].astype(str).str.startswith("C").sum()
print("Cancelled Orders:", cancelled_orders)
# Out:
# Cancelled Orders: 10206

# %%
negative_qty = (df_clean["Quantity"] < 0).sum()
print("Negative Quantity Records:", negative_qty)
# Out:
# Negative Quantity Records: 12326

# %%
invalid_price = (df_clean["Price"] <= 0).sum()
print("Zero or Negative Price Records:", invalid_price)
# Out:
# Zero or Negative Price Records: 3690

# %%
missing_customer = df_clean["Customer ID"].isnull().sum()
print("Missing Customer IDs:", missing_customer)
# Out:
# Missing Customer IDs: 107927

# %%
print("Rows before removing duplicates:", df_clean.shape)

df_clean = df_clean.drop_duplicates()

print("Rows after removing duplicates:", df_clean.shape)
# Out:
# Rows before removing duplicates: (525461, 8)
# Rows after removing duplicates: (518596, 8)

# %%
print("Rows before removing cancelled invoices:", df_clean.shape)

df_clean = df_clean[
    ~df_clean["Invoice"].astype(str).str.startswith("C")
]

print("Rows after removing cancelled invoices:", df_clean.shape)
# Out:
# Rows before removing cancelled invoices: (518596, 8)
# Rows after removing cancelled invoices: (508414, 8)

# %%
df_clean["Invoice"].str.startswith("C")
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 525456    NaN
# 525457    NaN
# 525458    NaN
# 525459    NaN
# 525460    NaN
# Name: Invoice, Length: 508414, dtype: object

# %%
print("Rows before removing negative quantities:", df_clean.shape)

df_clean = df_clean[df_clean["Quantity"] > 0]

print("Rows after removing negative quantities:", df_clean.shape)
# Out:
# Rows before removing negative quantities: (508414, 8)
# Rows after removing negative quantities: (506293, 8)

# %%
print("Rows before removing invalid prices:", df_clean.shape)

df_clean = df_clean[df_clean["Price"] > 0]

print("Rows after removing invalid prices:", df_clean.shape)
# Out:
# Rows before removing invalid prices: (506293, 8)
# Rows after removing invalid prices: (504730, 8)

# %%
df_clean.shape
# Out:
# (504730, 8)

# %%
df_clean.to_csv("../data/cleaned_online_retail.csv", index=False)

print("✅ Cleaned dataset saved successfully!")
# Out:
# ✅ Cleaned dataset saved successfully!

# %%
df_clean["Revenue"] = df_clean["Quantity"] * df_clean["Price"]

df_clean.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  Revenue
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom     83.4
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom     81.0
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom     81.0
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom    100.8
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom     30.0

# %%
total_revenue = df_clean["Revenue"].sum()

print(f"Total Revenue: £{total_revenue:,.2f}")
# Out:
# Total Revenue: £10,271,762.66

# %%
total_orders = df_clean["Invoice"].nunique()

print("Total Orders:", total_orders)
# Out:
# Total Orders: 20951

# %%
total_customers = df_clean["Customer ID"].nunique()

print("Total Customers:", total_customers)
# Out:
# Total Customers: 4312

# %%
average_order_value = total_revenue / total_orders

print(f"Average Order Value: £{average_order_value:.2f}")
# Out:
# Average Order Value: £490.28

# %%
country_sales = (
    df_clean.groupby("Country")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

country_sales.head(10)
# Out:
# Country
# United Kingdom    8812311.833
# EIRE               380909.570
# Netherlands        268784.350
# Germany            202025.391
# France             147103.140
# Sweden              53501.990
# Denmark             50906.850
# Spain               47568.650
# Switzerland         43921.390
# Australia           31446.800
# Name: Revenue, dtype: float64

# %%
top_products = (
    df_clean.groupby("Description")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

top_products.head(10)
# Out:
# Description
# Manual                                 262589.86
# REGENCY CAKESTAND 3 TIER               169912.76
# WHITE HANGING HEART T-LIGHT HOLDER     160345.63
# DOTCOM POSTAGE                         116408.71
# ASSORTED COLOUR BIRD ORNAMENT           72890.19
# PAPER CHAIN KIT 50'S CHRISTMAS          58127.30
# JUMBO BAG RED RETROSPOT                 56480.46
# PARTY BUNTING                           49664.12
# POSTAGE                                 49477.54
# ROTATING SILVER ANGELS T-LIGHT HLDR     47954.49
# Name: Revenue, dtype: float64

# %%
df_clean["Month"] = df_clean["InvoiceDate"].dt.to_period("M")

monthly_sales = (
    df_clean.groupby("Month")["Revenue"]
    .sum()
)

monthly_sales
# Out:
# Month
# 2009-12     822483.950
# 2010-01     651155.112
# 2010-02     551504.726
# 2010-03     830915.261
# 2010-04     678875.252
# 2010-05     657705.500
# 2010-06     749537.310
# 2010-07     648810.270
# 2010-08     695251.910
# 2010-09     921696.991
# 2010-10    1161902.220
# 2010-11    1464293.142
# 2010-12     437631.020
# Freq: M, Name: Revenue, dtype: float64

# %%
import matplotlib.pyplot as plt

monthly_sales.plot(kind="line", figsize=(12,6), marker="o")

plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue (£)")
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2
#       3 monthly_sales.plot(kind="line", figsize=(12,6), marker="o")
#       4
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import pandas as pd

# %%
file_path = "../data/online_retail_II.xlsx"

df = pd.read_excel(file_path)

# %%
df_clean = df.copy()

# %%
df_clean = df_clean.drop_duplicates()

df_clean = df_clean[
    ~df_clean["Invoice"].astype(str).str.startswith("C")
]

df_clean = df_clean[df_clean["Quantity"] > 0]

df_clean = df_clean[df_clean["Price"] > 0]

# %%
df_clean["Revenue"] = df_clean["Quantity"] * df_clean["Price"]

# %%
df_clean["Month"] = df_clean["InvoiceDate"].dt.to_period("M")

monthly_sales = (
    df_clean.groupby("Month")["Revenue"]
    .sum()
)

# %%
import matplotlib.pyplot as plt

# %%
monthly_sales.plot(kind="line", figsize=(12,6), marker="o")

plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue (£)")
plt.grid(True)

plt.show()

# %%
country_sales = (
    df_clean.groupby("Country")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

country_sales.head(10)
# Out:
# Country
# United Kingdom    8812311.833
# EIRE               380909.570
# Netherlands        268784.350
# Germany            202025.391
# France             147103.140
# Sweden              53501.990
# Denmark             50906.850
# Spain               47568.650
# Switzerland         43921.390
# Australia           31446.800
# Name: Revenue, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

country_sales.head(10).plot(kind="bar")

plt.title("Top 10 Countries by Revenue")
plt.xlabel("Country")
plt.ylabel("Revenue (£)")
plt.xticks(rotation=45)

plt.show()
